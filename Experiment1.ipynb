# %%
from google.colab import files
upload  = files.upload()
# Out:
#      <input type="file" id="files-62305fcc-7ac0-4b27-b5d6-ebab884c5546" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62305fcc-7ac0-4b27-b5d6-ebab884c5546">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
files.download('BD1.py')

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
pip install polygot
# Out:
# Collecting polygot
#   Downloading https://files.pythonhosted.org/packages/d2/1c/2324b7af3d6c2570d19f3d8c8f390ed6e7411432d1115ff8ea1421569107/polygot-0.1.tar.gz (25.7MB)
#      |████████████████████████████████| 25.7MB 119kB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from polygot) (3.13)
# Collecting fundamentals
#   Downloading https://files.pythonhosted.org/packages/77/6a/2c19c2ac07f5b33f0549236e54098c607df6be074ab4091cf4e1094882f7/fundamentals-2.3.1-py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 11.2MB/s
# Collecting readability-api
#   Downloading https://files.pythonhosted.org/packages/46/ab/4c7c3204959d1c24980f823e6ee1da636e1e541e81409cf01591f22eb3c9/readability-api-1.0.2.tar.gz
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from polygot) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from fundamentals->polygot) (2.8.1)
# Requirement already satisfied: docopt in /usr/local/lib/python3.6/dist-packages (from fundamentals->polygot) (0.6.2)
# Collecting coloredlogs
#   Downloading https://files.pythonhosted.org/packages/84/a6/837dbf6eac344cb74f0ba86b79e8180855570af3e26bcb1ea5f650cf944c/coloredlogs-15.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.6MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (from fundamentals->polygot) (5.4.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from fundamentals->polygot) (0.16.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from readability-api->polygot) (3.6.4)
# Requirement already satisfied: requests_oauthlib in /usr/local/lib/python3.6/dist-packages (from readability-api->polygot) (1.3.0)
# Collecting httplib2==0.9.1
#   Downloading https://files.pythonhosted.org/packages/38/9c/cd76fde3a74d36a0317422dee019ae5f73ce27e62d817ca003e018d9f9d8/httplib2-0.9.1.tar.gz (205kB)
#      |████████████████████████████████| 215kB 59.6MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->polygot) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->polygot) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->polygot) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->polygot) (2020.12.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil->fundamentals->polygot) (1.15.0)
# Collecting humanfriendly>=9.1
#   Downloading https://files.pythonhosted.org/packages/93/66/363d01a81da2108a5cf446daf619779f06d49a0c4426dd02b40734f10e2f/humanfriendly-9.1-py2.py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 11.7MB/s
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->readability-api->polygot) (20.3.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->readability-api->polygot) (0.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->readability-api->polygot) (51.3.3)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->readability-api->polygot) (8.6.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->readability-api->polygot) (1.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->readability-api->polygot) (1.10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests_oauthlib->readability-api->polygot) (3.1.0)
# Building wheels for collected packages: polygot, readability-api, httplib2
#   Building wheel for polygot (setup.py) ... done
#   Created wheel for polygot: filename=polygot-0.1-cp36-none-any.whl size=25747538 sha256=5e857bfdb6d0cca38973afdd4870cf85bebcb05a1ccfe7033530627053d38524
#   Stored in directory: /root/.cache/pip/wheels/f3/39/bb/0a20e71d7cfbd9dd1b6f07b45f70487a9d25b13501d9fe834c
#   Building wheel for readability-api (setup.py) ... done
#   Created wheel for readability-api: filename=readability_api-1.0.2-cp36-none-any.whl size=9504 sha256=e49fb8d24bcf228b28fb2997028f4cab3799695e37a1ecba005e9e8164948f1a
#   Stored in directory: /root/.cache/pip/wheels/b1/2d/ca/66db36427ae1f332caf6b3540cb722d4c32f4b71f95b27dafa
#   Building wheel for httplib2 (setup.py) ... done
#   Created wheel for httplib2: filename=httplib2-0.9.1-cp36-none-any.whl size=84024 sha256=a16cb319cb72e14571200e594b01e04895d925cb74978fca7eaa6fa1f7e0a1fc
#   Stored in directory: /root/.cache/pip/wheels/49/97/6e/e26b15a6262efbc29a2e793009359326ac1587a84cdd7acf74
# Successfully built polygot readability-api httplib2
# ERROR: google-api-python-client 1.7.12 has requirement httplib2<1dev,>=0.17.0, but you'll have httplib2 0.9.1 which is incompatible.
# ERROR: earthengine-api 0.1.238 has requirement httplib2<1dev,>=0.9.2, but you'll have httplib2 0.9.1 which is incompatible.
# Installing collected packages: humanfriendly, coloredlogs, fundamentals, httplib2, readability-api, polygot
#   Found existing installation: httplib2 0.17.4
#     Uninstalling httplib2-0.17.4:
#       Successfully uninstalled httplib2-0.17.4
# Successfully installed coloredlogs-15.0 fundamentals-2.3.1 httplib2-0.9.1 humanfriendly-9.1 polygot-0.1 readability-api-1.0.2

# %%
from matplotlib import pyplot as plt
x = [1,2,3,4,5,6]
y = [1,2,3,4,5,6]
plt.bar(x,y)
plt.show()

# %%
import numpy as np
arr = np.array([[7,8,9],[1,2,3]])
print(arr.shape)
# Out:
# (2, 3)

# %%
for x in np.nditer(arr):
  print(x)
# Out:
# 7
# 8
# 9
# 1
# 2
# 3

# %%
ar = np.array(([1,2,3],[7,8,9]))
ar = ar + arr
print(ar)
# Out:
# [[ 8 10 12]
#  [ 8 10 12]]

# %%
f = np.arange(10,5,-2)
print(f)
# Out:
# [10  8  6]

# %%
t = np.array([[1,2],[3,4],[5,6]])
ar = ar.dot(t)
print(ar)
# Out:
# [[ 98 128]
#  [ 98 128]]

# %%
z = ar.flatten()
print(z)
# Out:
# [ 98 128  98 128]

# %%
temp = t[:2,::1]
print(temp)
# Out:
# [[1 2]
#  [3 4]]
