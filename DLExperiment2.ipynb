# %%
import pandas as pd
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#df = pd.read_csv("Automobile_data.csv")
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Automobile_data.csv',dtype=str)
df.head(10)
# Out:
#   index      company   body-style  ... horsepower average-mileage  price
# 0     0  alfa-romero  convertible  ...        111              21  13495
# 1     1  alfa-romero  convertible  ...        111              21  16500
# 2     2  alfa-romero    hatchback  ...        154              19  16500
# 3     3         audi        sedan  ...        102              24  13950
# 4     4         audi        sedan  ...        115              18  17450
# 5     5         audi        sedan  ...        110              19  15250
# 6     6         audi        wagon  ...        110              19  18920
# 7     9          bmw        sedan  ...        101              23  16430
# 8    10          bmw        sedan  ...        101              23  16925
# 9    11          bmw        sedan  ...        121              21  20970
#
# [10 rows x 10 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.drop('index' , axis = 'columns' , inplace = True)

# %%
df.head(10)
# Out:
#        company   body-style wheel-base  ... horsepower average-mileage  price
# 0  alfa-romero  convertible       88.6  ...        111              21  13495
# 1  alfa-romero  convertible       88.6  ...        111              21  16500
# 2  alfa-romero    hatchback       94.5  ...        154              19  16500
# 3         audi        sedan       99.8  ...        102              24  13950
# 4         audi        sedan       99.4  ...        115              18  17450
# 5         audi        sedan       99.8  ...        110              19  15250
# 6         audi        wagon      105.8  ...        110              19  18920
# 7          bmw        sedan      101.2  ...        101              23  16430
# 8          bmw        sedan      101.2  ...        101              23  16925
# 9          bmw        sedan      101.2  ...        121              21  20970
#
# [10 rows x 9 columns]

# %%
df.tail(5)
# Out:
#        company body-style wheel-base  ... horsepower average-mileage  price
# 56  volkswagen      sedan       97.3  ...         85              27   7975
# 57  volkswagen      sedan       97.3  ...         52              37   7995
# 58  volkswagen      sedan       97.3  ...        100              26   9995
# 59       volvo      sedan      104.3  ...        114              23  12940
# 60       volvo      wagon      104.3  ...        114              23  13415
#
# [5 rows x 9 columns]

# %%
o1 = df.groupby('company')
toyotaDf = o1.get_group('toyota')
toyotaDf
# Out:
#    company body-style wheel-base  ... horsepower average-mileage  price
# 48  toyota  hatchback       95.7  ...         62              35   5348
# 49  toyota  hatchback       95.7  ...         62              31   6338
# 50  toyota  hatchback       95.7  ...         62              31   6488
# 51  toyota      wagon       95.7  ...         62              31   6918
# 52  toyota      wagon       95.7  ...         62              27   7898
# 53  toyota      wagon       95.7  ...         62              27   8778
# 54  toyota      wagon      104.5  ...        156              19  15750
#
# [7 rows x 9 columns]

# %%
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# volkswagen       4
# audi             4
# mercedes-benz    4
# mitsubishi       4
# chevrolet        3
# isuzu            3
# alfa-romero      3
# honda            3
# jaguar           3
# porsche          3
# volvo            2
# dodge            2
# Name: company, dtype: int64

# %%
car_Manufacturers = df.groupby('company')
priceDf = car_Manufacturers['company','price'].max()
priceDf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-20572cef35dd> in <module>()
#       1 car_Manufacturers = df.groupby('company')
# ----> 2 priceDf = car_Manufacturers['company','price'].max()
#       3 priceDf
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in max(self, numeric_only, min_count)
#    1558     def max(self, numeric_only: bool = False, min_count: int = -1):
#    1559         return self._agg_general(
# -> 1560             numeric_only=numeric_only, min_count=min_count, alias="max", npfunc=np.max
#    1561         )
#    1562
#
# ...

# %%
car_Manufacturers = df.groupby('company')
mileageDf = car_Manufacturers['company','average-mileage'].mean()
mileageDf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-35-ac7cd2c61296> in <module>()
#       1 car_Manufacturers = df.groupby('company')
# ----> 2 mileageDf = car_Manufacturers['company','average-mileage'].mean()
#       3 mileageDf
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1396             "mean",
#    1397             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1398             numeric_only=numeric_only,
#    1399         )
#    1400
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
# ...

# %%
carsDf = df.sort_values(by = ['price'])
carsDf.head(5)
# Out:
#    company body-style wheel-base  ... horsepower average-mileage  price
# 20   honda      sedan       96.5  ...        100              25  10345
# 30   mazda  hatchback       95.3  ...        101              17  11845
# 59   volvo      sedan      104.3  ...        114              23  12940
# 19   honda      sedan       96.5  ...        101              24  12945
# 60   volvo      wagon      104.3  ...        114              23  13415
#
# [5 rows x 9 columns]
